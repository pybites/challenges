# %%
from music_search import find_mp3_files

# %%
songs = find_mp3_files('/users/dshorstein/music/logic/tbd songs/')

# %%
songs
# Out:
#                                             Directory  \
# 0   /users/dshorstein/music/logic/tbd songs/Best B...
# 1   /users/dshorstein/music/logic/tbd songs/Best B...
# 2   /users/dshorstein/music/logic/tbd songs/Best B...
# 3   /users/dshorstein/music/logic/tbd songs/Best B...
# 4   /users/dshorstein/music/logic/tbd songs/Best B...
# 5   /users/dshorstein/music/logic/tbd songs/Best B...
# 6      /users/dshorstein/music/logic/tbd songs/Closed
# 7      /users/dshorstein/music/logic/tbd songs/Closed
# 8      /users/dshorstein/music/logic/tbd songs/Closed
# 9      /users/dshorstein/music/logic/tbd songs/Closed
# 10     /users/dshorstein/music/logic/tbd songs/Closed
# 11  /users/dshorstein/music/logic/tbd songs/Got to...
# 12  /users/dshorstein/music/logic/tbd songs/Got to...
# 13  /users/dshorstein/music/logic/tbd songs/Got to...
# 14  /users/dshorstein/music/logic/tbd songs/Got to...
# 15  /users/dshorstein/music/logic/tbd songs/Got to...
# ...
