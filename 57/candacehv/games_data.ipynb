# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
labels = pd.read_csv('C:\Users\orhol\Desktop\Data\olympic-games\dictionary.csv')
summer = pd.read_csv('C:\Users\orhol\Desktop\Data\olympic-games\summer.csv')
winter = pd.read_csv('C:\Users\orhol\Desktop\Data\olympic-games\winter.csv')

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# ...

# %%
summer.tail()
# Out:
#        Year    City      Sport           Discipline  \
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender     Event   Medal
# 31160         JANIKOWSKI, Damian     POL    Men  Wg 84 KG  Bronze
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# 31162             TOTROV, Rustam     RUS    Men  Wg 96 KG  Silver
# 31163          ALEKSANYAN, Artur     ARM    Men  Wg 96 KG  Bronze
# 31164             LIDBERG, Jimmy     SWE    Men  Wg 96 KG  Bronze
#        Year    City      Sport           Discipline  \
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# ...

# %%
winter.head(10)
# Out:
#    Year      City     Sport Discipline               Athlete Country Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA    Men
# 2  1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA    Men
# 3  1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA    Men
# 4  1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI    Men
# 5  1924  Chamonix  Biathlon   Biathlon       JULEN, Alphonse     SUI    Men
# 6  1924  Chamonix  Biathlon   Biathlon           JULEN, Ant.     SUI    Men
# 7  1924  Chamonix  Biathlon   Biathlon           VAUCHER, D.     SUI    Men
# 8  1924  Chamonix  Biathlon   Biathlon          BREMER, V.E.     FIN    Men
# 9  1924  Chamonix  Biathlon   Biathlon         ESKELINEN, A.     FIN    Men
#
#              Event   Medal
# 0  Military Patrol  Bronze
# 1  Military Patrol  Bronze
# 2  Military Patrol  Bronze
# ...

# %%
labels.head(5)
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
# How many events are there
summer.shape
winter.shape
# Out:
# (5770, 9)
# (5770, 9)

# %%
# How many countries are competing? 201
labels.shape
# Out:
# (201, 4)
# (201, 4)

# %%
# Who won the most medals?
summer.Athlete.value_counts()
# Out:
# PHELPS, Michael                   22
# LATYNINA, Larisa                  18
# ANDRIANOV, Nikolay                15
# SHAKHLIN, Boris                   13
# MANGIAROTTI, Edoardo              13
# ONO, Takashi                      13
# NURMI, Paavo                      12
# TORRES, Dara                      12
# KATO, Sawao                       12
# NEMOV, Alexei                     12
# COUGHLIN, Natalie                 12
# THOMPSON, Jenny                   12
# FISCHER, Birgit                   12
# SPITZ, Mark                       11
# CHUKARIN, Viktor Ivanovich        11
# CASLAVSKA, Vera                   11
# LOCHTE, Ryan                      11
# OSBURN, Carl Townsend             11
# BIONDI, Matthew                   11
# DITYATIN, Aleksandr               10
# LEWIS, Carl                       10
# HALL, Gary Jr.                    10
# ASTAKHOVA, Polina                 10
# KELETI, Agnes                     10
# VAN ALMSICK, Franziska            10
# ...

# %%
#Which countries won the most medals in Men's competitions?
summer.Country[summer.Gender == 'Men'].value_counts()
# Out:
# USA    3208
# URS    1476
# GBR    1412
# FRA    1254
# ITA    1161
# SWE     953
# GER     916
# HUN     834
# AUS     696
# JPN     525
# NED     495
# GDR     456
# FIN     443
# NOR     432
# CAN     428
# DEN     416
# POL     411
# RUS     409
# BEL     391
# FRG     375
# YUG     373
# SUI     353
# ESP     332
# CUB     310
# ROU     305
# BRA     303
# KOR     288
# CHN     270
# TCH     249
# BUL     215
#        ...
# LUX       2
# ECU       2
# ZAM       2
# MRI       1
# AHO       1
# GUY       1
# BER       1
# TOG       1
# GUA       1
# UAE       1
# IOP       1
# BAR       1
# DJI       1
# SUD       1
# BDI       1
# SRI       1
# BOT       1
# ERI       1
# CIV       1
# GRN       1
# VIE       1
# IRQ       1
# CYP       1
# GAB       1
# MKD       1
# ISV       1
# SEN       1
# TGA       1
# NIG       1
# SIN       1
# Name: Country, Length: 141, dtype: int64
# USA    3208
# URS    1476
# GBR    1412
# FRA    1254
# ITA    1161
# SWE     953
# GER     916
# ...

# %%
#Which countries won the most medals in women's competitions?
summer.Country[summer.Gender == 'Women'].value_counts()
# Out:
# USA    1377
# URS     573
# CHN     537
# AUS     493
# GER     389
# GDR     369
# RUS     359
# NED     356
# ROU     335
# GBR     308
# JPN     263
# HUN     245
# KOR     241
# CAN     221
# FRA     142
# ITA     135
# BRA     128
# NOR     122
# BUL     118
# FRG     115
# ESP     110
# CUB     100
# POL     100
# EUN      94
# DEN      91
# SWE      91
# UKR      89
# TCH      80
# ARG      72
# JAM      69
#        ...
# SGP       4
# SIN       3
# ALG       3
# MGL       3
# ZZX       3
# CMR       3
# IND       3
# VEN       2
# MOZ       2
# HKG       2
# IOP       2
# ANZ       2
# SRB       2
# BRN       1
# LAT       1
# ISL       1
# EGY       1
# SRI       1
# CHI       1
# MAS       1
# SYR       1
# EST       1
# TUN       1
# SCG       1
# UZB       1
# BOH       1
# VIE       1
# TJK       1
# ISR       1
# GEO       1
# Name: Country, Length: 95, dtype: int64
# USA    1377
# URS     573
# CHN     537
# AUS     493
# GER     389
# GDR     369
# RUS     359
# ...

# %%
graph = summer.Country.value_counts().sort_values(ascending = False)
graph.head(10).plot(kind='bar')
